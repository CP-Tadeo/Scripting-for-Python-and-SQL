# %%
content = """
<tr>
<td>EXPLOIT-DB:10102</td>
<td> <a href="http://cve.mitre.org/cgi-bin/cvename.cgi?name=CVE-2009-4186">CVE-2009-4186</a>
</td>
</tr>

<tr>
<td>EXPLOIT-DB:1013</td>
<td> <a href="http://cve.mitre.org/cgi-bin/cvename.cgi?name=CVE-2005-1598">CVE-2005-1598</a>
</td>
</tr>

<tr>
<td>EXPLOIT-DB:10168</td>
<td> <a href="http://cve.mitre.org/cgi-bin/cvename.cgi?name=CVE-2009-4767">CVE-2009-4767</a>
</td>
</tr>

<tr>
<td>EXPLOIT-DB:10180</td>
<td> <a href="http://cve.mitre.org/cgi-bin/cvename.cgi?name=CVE-2009-4091">CVE-2009-4091</a> <a href="http://cve.mitre.org/cgi-bin/cvename.cgi?name=CVE-2009-4092">CVE-2009-4092</a> <a href="http://cve.mitre.org/cgi-bin/cvename.cgi?name=CVE-2009-4093">CVE-2009-4093</a>
</td>
</tr>

<tr>
<td>EXPLOIT-DB:10183</td>
<td> <a href="http://cve.mitre.org/cgi-bin/cvename.cgi?name=CVE-2011-4906">CVE-2011-4906</a>
</td>
</tr>

<tr>
<td>EXPLOIT-DB:10201</td>
<td> <a href="http://cve.mitre.org/cgi-bin/cvename.cgi?name=CVE-2009-4781">CVE-2009-4781</a>
</td>
</tr>

<tr>
<td>EXPLOIT-DB:10216</td>
<td> <a href="http://cve.mitre.org/cgi-bin/cvename.cgi?name=CVE-2009-4223">CVE-2009-4223</a>
</td>
</tr>

<tr>
<td>EXPLOIT-DB:10217</td>
<td> <a href="http://cve.mitre.org/cgi-bin/cvename.cgi?name=CVE-2009-4779">CVE-2009-4779</a>
</td>
</tr>

<tr>
<td>EXPLOIT-DB:10218</td>
<td> <a href="http://cve.mitre.org/cgi-bin/cvename.cgi?name=CVE-2009-4082">CVE-2009-4082</a>
</td>
</tr>

<tr>
<td>EXPLOIT-DB:10220</td>
<td> <a href="http://cve.mitre.org/cgi-bin/cvename.cgi?name=CVE-2009-4220">CVE-2009-4220</a>
</td>
</tr>

<tr>
<td>EXPLOIT-DB:10226</td>
<td> <a href="http://cve.mitre.org/cgi-bin/cvename.cgi?name=CVE-2009-4097">CVE-2009-4097</a>
</td>
</tr>

<tr>
<td>EXPLOIT-DB:10231</td>
<td> <a href="http://cve.mitre.org/cgi-bin/cvename.cgi?name=CVE-2009-4096">CVE-2009-4096</a>
</td>
</tr>

<tr>
<td>EXPLOIT-DB:10245</td>
<td> <a href="http://cve.mitre.org/cgi-bin/cvename.cgi?name=CVE-2009-4221">CVE-2009-4221</a>
</td>
</tr>

<tr>
<td>EXPLOIT-DB:10246</td>
<td> <a href="http://cve.mitre.org/cgi-bin/cvename.cgi?name=CVE-2009-4224">CVE-2009-4224</a>
</td>
</tr>

<tr>
<td>EXPLOIT-DB:10258</td>
<td> <a href="http://cve.mitre.org/cgi-bin/cvename.cgi?name=CVE-2009-4194">CVE-2009-4194</a>
</td>
</tr>

<tr>
<td>EXPLOIT-DB:10259</td>
<td> <a href="http://cve.mitre.org/cgi-bin/cvename.cgi?name=CVE-2009-4156">CVE-2009-4156</a>
</td>
</tr>

<tr>
<td>EXPLOIT-DB:10276</td>
<td> <a href="http://cve.mitre.org/cgi-bin/cvename.cgi?name=CVE-2009-4196">CVE-2009-4196</a> <a href="http://cve.mitre.org/cgi-bin/cvename.cgi?name=CVE-2009-4197">CVE-2009-4197</a>
</td>
</tr>

<tr>
<td>EXPLOIT-DB:10299</td>
<td> <a href="http://cve.mitre.org/cgi-bin/cvename.cgi?name=CVE-2009-4263">CVE-2009-4263</a>
</td>
</tr>

<tr>
<td>EXPLOIT-DB:10300</td>
<td> <a href="http://cve.mitre.org/cgi-bin/cvename.cgi?name=CVE-2009-4252">CVE-2009-4252</a>
</td>
</tr>

<tr>
<td>EXPLOIT-DB:10301</td>
<td> <a href="http://cve.mitre.org/cgi-bin/cvename.cgi?name=CVE-2009-4255">CVE-2009-4255</a>
</td>
</tr>

<tr>
<td>EXPLOIT-DB:10329</td>
<td> <a href="http://cve.mitre.org/cgi-bin/cvename.cgi?name=CVE-2009-4264">CVE-2009-4264</a>
</td>
</tr>

<tr>
<td>EXPLOIT-DB:10330</td>
<td> <a href="http://cve.mitre.org/cgi-bin/cvename.cgi?name=CVE-2009-4569">CVE-2009-4569</a>
</td>
</tr>

<tr>
<td>EXPLOIT-DB:10336</td>
<td> <a href="http://cve.mitre.org/cgi-bin/cvename.cgi?name=CVE-2009-4266">CVE-2009-4266</a>
</td>
</tr>

<tr>
<td>EXPLOIT-DB:10338</td>
<td> <a href="http://cve.mitre.org/cgi-bin/cvename.cgi?name=CVE-2009-4413">CVE-2009-4413</a>
</td>
</tr>

<tr>
<td>EXPLOIT-DB:10354</td>
<td> <a href="http://cve.mitre.org/cgi-bin/cvename.cgi?name=CVE-2009-4567">CVE-2009-4567</a>
</td>
</tr>

<tr>
<td>EXPLOIT-DB:10358</td>
<td> <a href="http://cve.mitre.org/cgi-bin/cvename.cgi?name=CVE-2009-4256">CVE-2009-4256</a>
</td>
</tr>

<tr>
<td>EXPLOIT-DB:10361</td>
<td> <a href="http://cve.mitre.org/cgi-bin/cvename.cgi?name=CVE-2009-4600">CVE-2009-4600</a>
</td>
</tr>

<tr>
<td>EXPLOIT-DB:10366</td>
<td> <a href="http://cve.mitre.org/cgi-bin/cvename.cgi?name=CVE-2009-4599">CVE-2009-4599</a>
</td>
</tr>

<tr>
<td>EXPLOIT-DB:10367</td>
<td> <a href="http://cve.mitre.org/cgi-bin/cvename.cgi?name=CVE-2009-4598">CVE-2009-4598</a>
</td>
</tr>

<tr>
<td>EXPLOIT-DB:10369</td>
<td> <a href="http://cve.mitre.org/cgi-bin/cvename.cgi?name=CVE-2009-4604">CVE-2009-4604</a>
</td>
</tr>

<tr>
<td>EXPLOIT-DB:10370</td>
<td> <a href="http://cve.mitre.org/cgi-bin/cvename.cgi?name=CVE-2009-4596">CVE-2009-4596</a> <a href="http://cve.mitre.org/cgi-bin/cvename.cgi?name=CVE-2009-4597">CVE-2009-4597</a>
</td>
</tr>

<tr>
<td>EXPLOIT-DB:10387</td>
<td> <a href="http://cve.mitre.org/cgi-bin/cvename.cgi?name=CVE-2009-4320">CVE-2009-4320</a>
</td>
</tr>

<tr>
<td>EXPLOIT-DB:10393</td>
<td> <a href="http://cve.mitre.org/cgi-bin/cvename.cgi?name=CVE-2009-4386">CVE-2009-4386</a>
</td>
</tr>"""

# %%
from html.parser import HTMLParser

class Parser(HTMLParser):
    
    def __init__(self):
        super().__init__()
        self.recording = False
        
    def handle_starttag(self, tag, attrs):
        #
        if tag == "a":
            self.recording = True
        else:
            self.recording = False
            
        a = 1
    
    def handle_data(self, data):
        b = 1
        if self.recording:
            print(f"Found anchor tag info: {data}")
            self.recording = False

# %%
p = Parser()
p.feed(content)
# Out:
# Found anchor tag info: CVE-2009-4186
# Found anchor tag info: CVE-2005-1598
# Found anchor tag info: CVE-2009-4767
# Found anchor tag info: CVE-2009-4091
# Found anchor tag info: CVE-2009-4092
# Found anchor tag info: CVE-2009-4093
# Found anchor tag info: CVE-2011-4906
# Found anchor tag info: CVE-2009-4781
# Found anchor tag info: CVE-2009-4223
# Found anchor tag info: CVE-2009-4779
# Found anchor tag info: CVE-2009-4082
# Found anchor tag info: CVE-2009-4220
# Found anchor tag info: CVE-2009-4097
# Found anchor tag info: CVE-2009-4096
# Found anchor tag info: CVE-2009-4221
# Found anchor tag info: CVE-2009-4224
# Found anchor tag info: CVE-2009-4194
# Found anchor tag info: CVE-2009-4156
# Found anchor tag info: CVE-2009-4196
# Found anchor tag info: CVE-2009-4197
# Found anchor tag info: CVE-2009-4263
# Found anchor tag info: CVE-2009-4252
# Found anchor tag info: CVE-2009-4255
# Found anchor tag info: CVE-2009-4264
# Found anchor tag info: CVE-2009-4569
# ...
